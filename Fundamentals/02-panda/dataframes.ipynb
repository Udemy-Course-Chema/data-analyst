# %% [markdown]
# # Dataframes

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# WEBBROWSER IS DEAD!!!
#import webbrowser
#website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
#website2 = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'
#website3 = 'https://www.dropbox.com/s/er2b3o390w82pg0/nfl_rank_data.txt?dl=0'
#mySite = 'https://docs.google.com/spreadsheets/d/1KTZ_-seL40zqiYEz92O7y1Ss7zxnFdAQvH_5l4BwGkQ/edit#gid=0'
#webbrowser.open(mySite)

# %%
# IMPORT CSV
path = './dataframe/nfl_data.csv'

# %%
nfl_frame = pd.read_csv(path)
nfl_frame
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference
# 0          894   NFC East
# 1         1357  NFC North
# 2         1339  NFC North
# 3          792   AFC East
# 4          326  AFC North

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied*', 'Pct.', 'First Season',
#        'Total Games', 'Conference'],
#       dtype='object')

# %%
nfl_frame.Rank
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank, dtype: int64

# %%
nfl_frame.Team
# Out:
# 0       Dallas Cowboys
# 1        Chicago Bears
# 2    Green Bay Packers
# 3       Miami Dolphins
# 4     Baltimore Ravens
# Name: Team, dtype: object

# %%
nfl_frame['First Season']
# Out:
# 0    1960
# 1    1920
# 2    1921
# 3    1966
# 4    1996
# Name: First Season, dtype: int64

# %%
DataFrame(nfl_frame, columns=['Team','First Season','Total Games'])
# Out:
#                 Team  First Season  Total Games
# 0     Dallas Cowboys          1960          894
# 1      Chicago Bears          1920         1357
# 2  Green Bay Packers          1921         1339
# 3     Miami Dolphins          1966          792
# 4   Baltimore Ravens          1996          326

# %%
DataFrame(nfl_frame, columns=['Team','First Season','Total Games', 'Stadium'])
# Out:
#                 Team  First Season  Total Games  Stadium
# 0     Dallas Cowboys          1960          894      NaN
# 1      Chicago Bears          1920         1357      NaN
# 2  Green Bay Packers          1921         1339      NaN
# 3     Miami Dolphins          1966          792      NaN
# 4   Baltimore Ravens          1996          326      NaN

# %%
nfl_frame
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference
# 0          894   NFC East
# 1         1357  NFC North
# 2         1339  NFC North
# 3          792   AFC East
# 4          326  AFC North

# %% [markdown]
# ## Head

# %%
nfl_frame.head()
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference
# 0          894   NFC East
# 1         1357  NFC North
# 2         1339  NFC North
# 3          792   AFC East
# 4          326  AFC North

# %%
nfl_frame.head(2)
# Out:
#    Rank            Team  Won  Lost  Tied*   Pct.  First Season  Total Games  \
# 0     1  Dallas Cowboys  510   378      6  0.574          1960          894
# 1     2   Chicago Bears  752   563     42  0.570          1920         1357
#
#   Conference
# 0   NFC East
# 1  NFC North

# %% [markdown]
# ## Tail

# %%
nfl_frame.tail()
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference
# 0          894   NFC East
# 1         1357  NFC North
# 2         1339  NFC North
# 3          792   AFC East
# 4          326  AFC North

# %%
nfl_frame.tail(2)
# Out:
#    Rank              Team  Won  Lost  Tied*   Pct.  First Season  Total Games  \
# 3     4    Miami Dolphins  443   345      4  0.562          1966          792
# 4     5  Baltimore Ravens  182   143      1  0.560          1996          326
#
#   Conference
# 3   AFC East
# 4  AFC North

# %% [markdown]
# ## Loc

# %%
nfl_frame
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference
# 0          894   NFC East
# 1         1357  NFC North
# 2         1339  NFC North
# 3          792   AFC East
# 4          326  AFC North

# %%
nfl_frame.loc[3]
# Out:
# Rank                         4
# Team            Miami Dolphins
# Won                        443
# Lost                       345
# Tied*                        4
# Pct.                     0.562
# First Season              1966
# Total Games                792
# Conference            AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = 'Levis Stadium'

# %%
nfl_frame
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference        Stadium
# 0          894   NFC East  Levis Stadium
# 1         1357  NFC North  Levis Stadium
# 2         1339  NFC North  Levis Stadium
# 3          792   AFC East  Levis Stadium
# 4          326  AFC North  Levis Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference  Stadium
# 0          894   NFC East        0
# 1         1357  NFC North        1
# 2         1339  NFC North        2
# 3          792   AFC East        3
# 4          326  AFC North        4

# %% [markdown]
# ## Match Stadium by index

# %%
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index=[4,0])
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums
nfl_frame
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference         Stadium
# 0          894   NFC East    AT&T Stadium
# 1         1357  NFC North             NaN
# 2         1339  NFC North             NaN
# 3          792   AFC East             NaN
# 4          326  AFC North  Levi's Stadium

# %% [markdown]
# ## Delete column

# %%
del nfl_frame['Stadium']
nfl_frame
# Out:
#    Rank               Team  Won  Lost  Tied*   Pct.  First Season  \
# 0     1     Dallas Cowboys  510   378      6  0.574          1960
# 1     2      Chicago Bears  752   563     42  0.570          1920
# 2     3  Green Bay Packers  741   561     37  0.567          1921
# 3     4     Miami Dolphins  443   345      4  0.562          1966
# 4     5   Baltimore Ravens  182   143      1  0.560          1996
#
#    Total Games Conference
# 0          894   NFC East
# 1         1357  NFC North
# 2         1339  NFC North
# 3          792   AFC East
# 4          326  AFC North

# %% [markdown]
# ## Dictionary

# %%
data = {
    'City':['SF','LA','NY'],
    'Population':[70000,50000,90000]
}

# %% [markdown]
# Convert to DataDrame

# %%
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   SF       70000
# 1   LA       50000
# 2   NY       90000

# %% [markdown]
# ## References

# %%
website_pandas = 'https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.DataFrame.html'
